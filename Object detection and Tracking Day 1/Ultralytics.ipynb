# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\ajant\anaconda3\lib\site-packages (8.4.127)
# Requirement already satisfied: filelock>=3.16.1 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (3.20.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (2.5.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (3.10.6)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.7.0 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: torch>=1.8.0 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (2.13.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (0.28.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (1.43.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.1.6 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (2.1.6)
# Requirement already satisfied: ultralytics-platform>=0.1.3 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics) (0.1.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajant\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajant\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajant\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajant\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajant\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajant\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajant\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.43.2 in c:\users\ajant\anaconda3\lib\site-packages (from polars>=0.20.0->ultralytics) (1.43.2)
# Requirement already satisfied: six>=1.5 in c:\users\ajant\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ajant\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajant\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajant\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajant\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.4.22)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ajant\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\ajant\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ajant\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ajant\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in c:\users\ajant\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ajant\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ajant\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.28 in c:\users\ajant\anaconda3\lib\site-packages (from ultralytics-platform>=0.1.3->ultralytics) (0.28.1)
# Requirement already satisfied: anyio in c:\users\ajant\anaconda3\lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.3->ultralytics) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ajant\anaconda3\lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.3->ultralytics) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ajant\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.28->ultralytics-platform>=0.1.3->ultralytics) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ajant\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.28->ultralytics-platform>=0.1.3->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ajant\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import ultralytics

print("Version: ", ultralytics.__version__)
# Out:
# Version:  8.4.127

# %%
# detection => yolo26n.pt
# classification => yolo26n-cls.pt
# segmentation=> yolo26n-seg.pt
# pose => yolo26n-pose.pt

# %%
from ultralytics import YOLO
import ultralytics
import time
models = ['yolo26n.pt','yolo26s.pt']
for path in models:
    try:
        model = YOLO(path)
        start = time.perf_counter()
        resutls = model("home.jpg")
        elapsed = (time.perf_counter()-start) * 1000
        print(path)
        print("inference time(ms):",round(elapsed,2))
        print("Detections:", len(resutls[0].boxes) if results[0].boxes is not None else 0)
    except Exception as exc:
        print(path, ":", exc)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 13.4MB/s 0.4s.3s<0.1s.5s
#
# image 1/1 C:\Users\ajant\Downloads\ProgNxt\Object detection and Tracking Day 1\home.jpg: 416x640 1 chair, 2 couchs, 4 potted plants, 116.4ms
# Speed: 3.7ms preprocess, 116.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
# yolo26n.pt
# inference time(ms): 217.29
# yolo26n.pt : name 'results' is not defined
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26s.pt to 'yolo26s.pt': 100% ━━━━━━━━━━━━ 19.5MB 15.3MB/s 1.3s1.2s<0.0s
#
# image 1/1 C:\Users\ajant\Downloads\ProgNxt\Object detection and Tracking Day 1\home.jpg: 416x640 3 chairs, 1 couch, 4 potted plants, 1 tv, 166.8ms
# Speed: 3.3ms preprocess, 166.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
# yolo26s.pt
# inference time(ms): 223.31
# yolo26s.pt : name 'results' is not defined

# %%
# sampl1

# %%
from ultralytics import YOLO
model = YOLO("yolo26n.pt")
result = model("home.jpg")

for res in result:
    res.show()
# Out:
# image 1/1 C:\Users\ajant\Downloads\ProgNxt\Object detection and Tracking Day 1\home.jpg: 416x640 1 chair, 2 couchs, 4 potted plants, 75.9ms
# Speed: 2.5ms preprocess, 75.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)

# %%
# save it in another file
from ultralytics import YOLO
model = YOLO("yolo26n.pt")
result = model("home.jpg")

for res in result:
    res.save(filename = "out.jpg")
# Out:
# image 1/1 C:\Users\ajant\Downloads\ProgNxt\Object detection and Tracking Day 1\home.jpg: 416x640 1 chair, 2 couchs, 4 potted plants, 85.7ms
# Speed: 3.3ms preprocess, 85.7ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)

# %%
# identify and specify the class
from ultralytics import YOLO
model = YOLO("yolo26n.pt")
result = model("home.jpg")

for res in result:
    for box in res.boxes:
        class_id = int(box.cls[0])
        confidence = float(box.conf[0])

        print("Class: ", class_id)
        print(" Confidence: ", confidence)
# Out:
# image 1/1 C:\Users\ajant\Downloads\ProgNxt\Object detection and Tracking Day 1\home.jpg: 416x640 1 chair, 2 couchs, 4 potted plants, 84.5ms
# Speed: 3.7ms preprocess, 84.5ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
# Class:  58
#  Confidence:  0.7777441740036011
# Class:  58
#  Confidence:  0.7763550281524658
# Class:  58
#  Confidence:  0.5239540338516235
# Class:  56
#  Confidence:  0.43052786588668823
# Class:  57
#  Confidence:  0.3885471522808075
# Class:  57
#  Confidence:  0.3693353235721588
# Class:  58
#  Confidence:  0.31198227405548096
